# %% [markdown]
# <a href="https://colab.research.google.com/github/rick77777/Coding/blob/master/A1_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Reading the Data

# %%
data_A = pd.read_csv('A1_dataA.tsv',sep='\t')
print(data_A)
# Out:
#           X1        X2        X3        X4        X5  class
# 0   0.941443  0.739137  0.789515  0.783686  0.165450      1
# 1   0.903789  0.774421  1.807503 -1.403254  0.531660      1
# 2   0.988921  0.763048  1.608549  0.354220  0.979188      1
# 3   0.945123  1.167735  1.140172 -0.749005  0.171429      0
# 4   0.912966  1.035160  0.548504  0.499823  0.084890      0
# ..       ...       ...       ...       ...       ...    ...
# 95  0.906970  0.596282  2.147693  0.734089  0.746213      0
# 96  1.017505  1.238252  0.304208 -0.718176  0.069258      0
# 97  0.955569  1.371617 -0.020880  0.168037  1.037322      1
# 98  0.913893  1.073605  1.403728  0.595783 -0.197168      0
# 99  0.927372  1.165750 -0.131283 -0.453920 -0.400558      0
#
# [100 rows x 6 columns]

# %%
data_B = pd.read_csv('A1_dataB.tsv',sep='\t')
print(data_B)
# Out:
#           X1        X2        X3        X4        X5  class
# 0   0.509022  0.977143  1.807426 -0.456832  1.114991      1
# 1   0.431006  0.340303 -0.991420 -0.533280  0.033497      1
# 2   0.601544  1.627891 -0.144424  0.070053  0.485216      1
# 3  -0.346139  0.435936  1.240060  0.286332  0.475602      1
# 4   1.669372  0.390462  1.225110 -0.809030  0.088785      1
# ..       ...       ...       ...       ...       ...    ...
# 95  0.109082  0.576463  0.748201  0.974792 -0.378810      0
# 96  0.965790  0.349732  0.800445  1.332569 -0.177653      0
# 97  0.214369  0.856750  0.799374  1.283464  0.129589      0
# 98 -1.260431  0.875636  0.489988 -0.015972 -0.142512      0
# 99 -0.622042  1.123325  0.292497  1.048208 -0.422344      0
#
# [100 rows x 6 columns]

# %%
X1_A = data_A['X1']
X2_A = data_A['X2']
X3_A = data_A['X3']
X4_A = data_A['X4']
X5_A = data_A['X5']
Y_A = data_A['class']

print("For Dataset A \n")
print("Max of X1 : ", np.max(X1_A), ", Min of X1", np.min(X1_A))
print("Max of X2 : ", np.max(X2_A), ", Min of X2", np.min(X2_A))
print("Max of X3 : ", np.max(X3_A), ", Min of X3", np.min(X3_A))
print("Max of X4 : ", np.max(X4_A), ", Min of X4", np.min(X4_A))
print("Max of X5 : ", np.max(X5_A), ", Min of X5", np.min(X5_A))
# Class_A
# Out:
# For Dataset A
#
# Max of X1 :  1.01750535945275 , Min of X1 0.876493435015979
# Max of X2 :  1.55646500343911 , Min of X2 -0.29733817435427
# Max of X3 :  2.14769347482251 , Min of X3 -1.95345061778471
# Max of X4 :  1.77122618039136 , Min of X4 -1.4032538336278
# Max of X5 :  1.25408565479721 , Min of X5 -0.579734647957053

# %%
X1_B = data_B['X1']
X2_B = data_B['X2']
X3_B = data_B['X3']
X4_B = data_B['X4']
X5_B = data_B['X5']
Y_B = data_B['class']

print("For Dataset B \n")
print("Max of X1 : ", np.max(X1_B), ", Min of X1", np.min(X1_B))
print("Max of X2 : ", np.max(X2_B), ", Min of X2", np.min(X2_B))
print("Max of X3 : ", np.max(X3_B), ", Min of X3", np.min(X3_B))
print("Max of X4 : ", np.max(X4_B), ", Min of X4", np.min(X4_B))
print("Max of X5 : ", np.max(X5_B), ", Min of X5", np.min(X5_B))
# Class_B
# Out:
# For Dataset B
#
# Max of X1 :  2.30039521588059 , Min of X1 -1.37395495966678
# Max of X2 :  3.0846238786814 , Min of X2 -1.31068838379644
# Max of X3 :  2.88534896499949 , Min of X3 -1.83973029067439
# Max of X4 :  1.8850669042681 , Min of X4 -1.66632953614064
# Max of X5 :  1.6491310335358 , Min of X5 -1.29668502632222

# %%
class_0_data = data_B[Y_B == 0]
class_1_data = data_B[Y_B == 1]

# %% [markdown]
# Visualizing the Data

# %%
# Creating a scatter plot

plt.scatter(class_0_data['X1'], class_0_data['X3'], color='blue', label='Class 0')
plt.scatter(class_1_data['X1'], class_1_data['X3'], color='red', marker = 'x', label='Class 1')

#plt.scatter(X3_B, X4_B, color = Class_B.map({0: 'Red', 1: 'Blue'}), marker='x')


# Adding labels and title
plt.xlabel('X1 Label')
plt.ylabel('X3 Label')
plt.title('Scatter Plot')

# Adding a legend
plt.legend()

# Displaying the plot
plt.show()

# %%
# Creating a scatter plot

plt.scatter(class_0_data['X2'], class_0_data['X3'], color='blue', label='Class 0')
plt.scatter(class_1_data['X2'], class_1_data['X3'], color='red', marker = 'x', label='Class 1')

#plt.scatter(X3_B, X4_B, color = Class_B.map({0: 'Red', 1: 'Blue'}), marker='x')


# Adding labels and title
plt.xlabel('X2 Label')
plt.ylabel('X3 Label')
plt.title('Scatter Plot')

# Adding a legend
plt.legend()

# Displaying the plot
plt.show()

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

# Generate synthetic data with 4 features
X = data_A.drop('class', axis = 1)  # 100 samples, 4 features
y = data_A['class']  # Two classes: 0 and 1

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# Create KNN classifier with k=3
knn_classifier = KNeighborsClassifier(n_neighbors=5)

# Train the classifier
knn_classifier.fit(X_train, y_train)

# Make predictions on the test set
y_pred = knn_classifier.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')

# Display classification report
print('Classification Report:')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.56
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.64      0.60      0.62        15
#            1       0.45      0.50      0.48        10
#
#     accuracy                           0.56        25
#    macro avg       0.55      0.55      0.55        25
# weighted avg       0.57      0.56      0.56        25

# %%
X_A = data_A.drop('class', axis = 1)
X_B = data_B.drop('class', axis = 1)
X_A
Y_A
# Out:
# 0     1
# 1     1
# 2     1
# 3     0
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    0
# 99    0
# Name: class, Length: 100, dtype: int64

# %% [markdown]
# #KNN for Dataset A

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_recall_curve, average_precision_score, accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
import matplotlib.pyplot as plt
import numpy as np

# Generate synthetic data with 4 features and 2 classes
# np.random.seed(42)
# X = np.random.rand(100, 5)
# y = np.random.choice([0, 1], 100)

# Initialize KNN classifier
knn_classifier = KNeighborsClassifier(n_neighbors=3)

# Initialize StratifiedKFold with 10 folds
stratified_kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)

# Lists to store metrics
all_y_true = []
all_y_scores = []
accuracies = []
precisions = []
recalls = []
f1_scores = []
auc = []

fold = 0
# Perform 10-fold stratified cross-validation
for train_index, test_index in stratified_kfold.split(X_A, Y_A):
    X_train, X_test = X_A.iloc[train_index], X_A.iloc[test_index]
    y_train, y_test = Y_A.iloc[train_index], Y_A.iloc[test_index]

    # Train the KNN classifier
    knn_classifier.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = knn_classifier.predict(X_test)
    y_pred_prob = knn_classifier.predict_proba(X_test)[:, 1]

    # Store true labels and predicted scores for each fold
    all_y_true.extend(y_test)
    all_y_scores.extend(y_pred_prob)

    # Calculate Precision-Recall curve
    precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)
    acc_score = accuracy_score(y_test, y_pred)
    f1_sc = f1_score(y_test, y_pred)
    auc_sc = roc_auc_score(y_test, y_pred_prob)

    print(f"================================================ Fold {fold} =================================================\n")
    # print(f"Accuracy : {acc_score:0.2f}, Precision : {precision:0.2f}, Recall : {recall:0.2f}, F1 Score : {f1_sc:0.2f} ")
    print(f"Accuracy : {acc_score:0.2f}")
    # print(f"Precision : {precision}")
    # print(f"Recall : {recall}")
    print(f"F1 Score : {f1_sc:0.2f}")
    # Plot Precision-Recall curve for each fold
    plt.plot(recall, precision, lw=3)
    fold += 1
    accuracies.append(acc_score)
    f1_scores.append(f1_sc)
    auc.append(auc_sc)

# Calculate and display average precision
avg_precision = average_precision_score(all_y_true, all_y_scores)
avg_recall = recall_score(all_y_true, (np.array(all_y_scores) > 0.5).astype(int))
print(f'Average Accuracy : {np.mean(accuracies):.2f}')
print(f'Average Precision: {avg_precision:.2f}')
print(f'Average Recall: {avg_recall:.2f}')
print(f'Average F1 Score : {np.mean(f1_scores):.2f}')
print(f'Average AUC Score : {np.mean(auc):.2f}')

# Calculate and display other performance metrics

# accuracy = accuracy_score(all_y_true, (np.array(all_y_scores) > 0.5).astype(int))
# f1 = f1_score(all_y_true, (np.array(all_y_scores) > 0.5).astype(int))
# precision = precision_score(all_y_true, (np.array(all_y_scores) > 0.5).astype(int))
# recall = recall_score(all_y_true, (np.array(all_y_scores) > 0.5).astype(int))



# Plot settings
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve for each Fold')
plt.show()
# Out:
# ================================================ Fold 0 =================================================
#
# Accuracy : 0.60
# F1 Score : 0.60
# ================================================ Fold 1 =================================================
#
# Accuracy : 0.30
# F1 Score : 0.36
# ================================================ Fold 2 =================================================
#
# Accuracy : 0.60
# F1 Score : 0.60
# ================================================ Fold 3 =================================================
#
# Accuracy : 0.50
# F1 Score : 0.29
# ================================================ Fold 4 =================================================
#
# Accuracy : 0.70
# F1 Score : 0.40
# ================================================ Fold 5 =================================================
#
# Accuracy : 0.40
# F1 Score : 0.25
# ================================================ Fold 6 =================================================
#
# ...

# %%
#for train_index, test_index in stratified_kfold.split(X_A, Y_A):
#  print(train_index)
#  print(test_index)
#X_train

# %%
X_A.iloc[[0,1,2,4]]
# Out:
#          X1        X2        X3        X4        X5
# 0  0.941443  0.739137  0.789515  0.783686  0.165450
# 1  0.903789  0.774421  1.807503 -1.403254  0.531660
# 2  0.988921  0.763048  1.608549  0.354220  0.979188
# 4  0.912966  1.035160  0.548504  0.499823  0.084890

# %% [markdown]
# #KNN for Dataset B

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_recall_curve, average_precision_score, accuracy_score, f1_score, precision_score, recall_score
import matplotlib.pyplot as plt
import numpy as np

# Initialize KNN classifier
knn_classifier = KNeighborsClassifier(n_neighbors=3)

# Initialize StratifiedKFold with 10 folds
stratified_kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)

# Lists to store metrics
all_y_true = []
all_y_scores = []

# Perform 10-fold stratified cross-validation
for train_index, test_index in stratified_kfold.split(X_B, Y_B):
    X_train, X_test = X_B.iloc[train_index], X_B.iloc[test_index]
    y_train, y_test = Y_B.iloc[train_index], Y_B.iloc[test_index]


    # Train the KNN classifier
    knn_classifier.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred_prob = knn_classifier.predict_proba(X_test)[:, 1]

    # Store true labels and predicted scores for each fold
    all_y_true.extend(y_test)
    all_y_scores.extend(y_pred_prob)

    # Calculate Precision-Recall curve
    precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)

    # Plot Precision-Recall curve for each fold
    plt.plot(recall, precision, lw=2)

# Calculate and display other performance metrics
accuracy = accuracy_score(all_y_true, (np.array(all_y_scores) > 0.5).astype(int))
f1 = f1_score(all_y_true, (np.array(all_y_scores) > 0.5).astype(int))
precision = precision_score(all_y_true, (np.array(all_y_scores) > 0.5).astype(int))
recall = recall_score(all_y_true, (np.array(all_y_scores) > 0.5).astype(int))

print(f'Accuracy: {accuracy:.2f}')
print(f'F1 Score: {f1:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')

# Plot settings
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve for each Fold')
plt.show()
# Out:
# Accuracy: 0.76
# F1 Score: 0.73
# Precision: 0.82
# Recall: 0.66

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(14, 10))
labels = ['X1', 'X2', 'X3', 'X4', 'X5']

X_A_0 = data_A[Y_A == 0].drop('class', axis = 1)
X_A_1 = data_A[Y_A == 1].drop('class', axis = 1)
X_B_0 = data_B[Y_B == 0].drop('class', axis = 1)
X_B_1 = data_B[Y_B == 1].drop('class', axis = 1)

axs[0,0].set_title('Dataset A Class 0 Violinplot', fontsize=12, fontweight='bold')
axs[0,0].violinplot(X_A_0, [1,2,3,4,5], showmeans=True, showextrema=True, showmedians=True, bw_method='silverman')
axs[0,0].set_ylabel('Observed values')

axs[0,1].set_title('Dataset A Class 1 Violinplot', fontsize=12, fontweight='bold')
parts_A = axs[0,1].violinplot(X_A_1, [1,2,3,4,5], showmeans=True, showextrema=True, showmedians=True, bw_method='silverman')
axs[0,1].set_ylabel('Observed values')

for pc in parts_A['bodies']:
    pc.set_facecolor('#D43F3A')
    pc.set_edgecolor('black')
    pc.set_alpha(0.6)

axs[1,0].set_title('Dataset B Class 0 Violinplot', fontsize=12, fontweight='bold')
axs[1,0].violinplot(X_B_0, [1,2,3,4,5], showmeans=True, showextrema=True, showmedians=True, bw_method='silverman')
axs[1,0].set_ylabel('Observed values')

axs[1,1].set_title('Dataset B Class 1 Violinplot', fontsize=12, fontweight='bold')
parts_B = axs[1,1].violinplot(X_B_1, [1,2,3,4,5], showmeans=True, showextrema=True, showmedians=True, bw_method='silverman')
axs[1,1].set_ylabel('Observed values')

for pc in parts_B['bodies']:
    pc.set_facecolor('#D43F3A')
    pc.set_edgecolor('black')
    pc.set_alpha(0.6)


axs[0,0].set_xticks(np.arange(1, len(labels) + 1), labels=labels)
axs[0,1].set_xticks(np.arange(1, len(labels) + 1), labels=labels)
axs[1,0].set_xticks(np.arange(1, len(labels) + 1), labels=labels)
axs[1,1].set_xticks(np.arange(1, len(labels) + 1), labels=labels)

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(14, 7))
labels = ['X1', 'X2', 'X3', 'X4', 'X5']

axs[0].set_title('Dataset A Class 0 Violinplot', fontsize=12, fontweight='bold')
axs[0].violinplot(X_A_0, [1,2,3,4,5], showmeans=True, showextrema=True)
axs[0].set_ylabel('Observed values')

axs[1].set_title('Dataset A Class 1 Violinplot', fontsize=12, fontweight='bold')
parts_A = axs[1].violinplot(X_A_1, [1,2,3,4,5], showmeans=True, showextrema=True)


for pc in parts_A['bodies']:
    pc.set_facecolor('#D43F3A')
    pc.set_edgecolor('black')
    pc.set_alpha(0.5)

axs[0].set_xticks(np.arange(1, len(labels) + 1), labels=labels)
axs[1].set_xticks(np.arange(1, len(labels) + 1), labels=labels)
axs[1].set_ylabel('Observed values')
# Out:
# Text(0, 0.5, 'Observed values')

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(14, 7))
labels = ['X1', 'X2', 'X3', 'X4', 'X5']

axs[0].set_title('Dataset B Class 0 Violinplot', fontsize=12, fontweight='bold')
axs[0].violinplot(X_B_0, [1,2,3,4,5], showmeans=True, showextrema=True)
axs[0].set_ylabel('Observed values')

axs[1].set_title('Dataset B Class 1 Violinplot', fontsize=12, fontweight='bold')
parts_B = axs[1].violinplot(X_B_1, [1,2,3,4,5], showmeans=True, showextrema=True)


for pc in parts_B['bodies']:
    pc.set_facecolor('#D43F3A')
    pc.set_edgecolor('black')
    pc.set_alpha(0.5)

axs[0].set_xticks(np.arange(1, len(labels) + 1), labels=labels)
axs[1].set_xticks(np.arange(1, len(labels) + 1), labels=labels)
axs[1].set_ylabel('Observed values')
# Out:
# Text(0, 0.5, 'Observed values')

# %%
'''
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(14, 7))
labels = ['Attribute 1', 'Attribute 2', 'Attribute 3', 'Attribute 4', 'Attribute 5']

axs[0].set_title('Dataset B Class 0 Violinplot', fontsize=12, fontweight='bold')
parts_B_0 = axs[0].violinplot(X_B_0, [1,2,3,4,5], showmeans=True, showextrema=True, showmedians=True)
axs[0].set_ylabel('Observed values')

axs[1].set_title('Dataset B Class 1 Violinplot', fontsize=12, fontweight='bold')
parts_B_1 = axs[1].violinplot(X_B_1, [1,2,3,4,5], showmeans=True, showextrema=True, showmedians=True)
axs[1].set_ylabel('Observed values')

for pc in parts_B_1['bodies']:
    pc.set_facecolor('#D43F3A')
    pc.set_edgecolor('black')
    pc.set_alpha(0.5)

for partname in ('cmins', 'cmaxes', 'cmeans'):
    vp0 = parts_B_0[partname]
    vp1 = parts_B_1[partname]
    vp0.set_edgecolor("red")
    vp0.set_linewidth(1)
    vp1.set_edgecolor("red")
    vp1.set_linewidth(1)

axs[0].set_xticks(np.arange(1, len(labels) + 1), labels=labels)
axs[1].set_xticks(np.arange(1, len(labels) + 1), labels=labels)
'''
# Out:
# '\nfig, axs = plt.subplots(nrows=1, ncols=2, figsize=(14, 7))\nlabels = [\'Attribute 1\', \'Attribute 2\', \'Attribute 3\', \'Attribute 4\', \'Attribute 5\']\n\naxs[0].set_title(\'Dataset B Class 0 Violinplot\', fontsize=12, fontweight=\'bold\')\nparts_B_0 = axs[0].violinplot(X_B_0, [1,2,3,4,5], showmeans=True, showextrema=True, showmedians=True)\naxs[0].set_ylabel(\'Observed values\')\n\naxs[1].set_title(\'Dataset B Class 1 Violinplot\', fontsize=12, fontweight=\'bold\')\nparts_B_1 = axs[1].violinplot(X_B_1, [1,2,3,4,5], showmeans=True, showextrema=True, showmedians=True)\naxs[1].set_ylabel(\'Observed values\')\n\nfor pc in parts_B_1[\'bodies\']:\n    pc.set_facecolor(\'#D43F3A\')\n    pc.set_edgecolor(\'black\')\n    pc.set_alpha(0.5)\n\nfor partname in (\'cmins\', \'cmaxes\', \'cmeans\'):\n    vp0 = parts_B_0[partname]\n    vp1 = parts_B_1[partname]\n    vp0.set_edgecolor("red")\n    vp0.set_linewidth(1)\n    vp1.set_edgecolor("red")\n    vp1.set_linewidth(1)\n\naxs[0].set_xticks(
# ...

# %%
import seaborn as sns
sns.set(style="white")
'''
for y_value in ["X1","X2","X3","X4","X5"] :
  sns.violinplot(y=y_value, hue="class", data=data_B, split=True, linewidth=1.5,
               inner="quart", palette={0: "b", 1: "y"})
               '''
##sns.despine(left=True)

class_ct = [0,1]
# Iterate through each class
for c in class_ct:
    # Subset to the airline
    subset = data_B[data_B['class'] == c]

    # Draw the density plot
    sns.distplot(subset['X3'], hist = False, kde = True,
                 kde_kws = {'fill': True,'linewidth': 2.5},
                 label = c)

# Plot formatting
plt.legend(prop={'size': 14}, title = 'Class')
plt.title('Density Plot with Attribute 1 (X1)')
plt.xlabel('Observed values of X1')
plt.ylabel('Density')
# Out:
# <ipython-input-19-2f592a67aa44>:17: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(subset['X3'], hist = False, kde = True,
# <ipython-input-19-2f592a67aa44>:17: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(subset['X3'], hist = False, kde = True,
# ...

# %%
fig, (ax1,ax2,ax3,ax4,ax5) = plt.subplots(nrows=1, ncols=5, figsize=(30, 8))
sns.set(style="white")
class_ct = [0,1]
# Iterate through each class
    # Draw the density plot
'''
for i in ['X1', 'X2', 'X3', 'X4', 'X5']:
  for c in class_ct:
    subset = data_A[data_A['class'] == c]
    sns.distplot(subset[i], hist = False, kde = True, kde_kws = {'fill': True,'linewidth': 2.5}, label = c)
    ax[int(i[1])-1].set_title('Density Plot with Attribute 1 ()')
    ax[int(i[1])-1].legend(prop={'size': 14}, title = 'Class')
    ax[int(i[1])-1].set_xlabel('Observed values of X')
    ax[int(i[1])-1].set_ylabel('Density')
'''

for c in class_ct:
    subset = data_A[data_A['class'] == c]
    sns.distplot(subset['X1'], hist = False, kde = True, kde_kws = {'fill': True,'linewidth': 2.5}, label = c,ax=ax1)
    ax1.set_title('Density Plot with Attribute 1 (X1)')
    ax1.legend(prop={'size': 14}, title = 'Class')
    ax1.set_xlabel('Observed values of X1')
    ax1.set_ylabel('Density')

for c in class_ct:
    subset = data_A[data_A['class'] == c]
    sns.distplot(subset['X2'], hist = False, kde = True, kde_kws = {'fill': True,'linewidth': 2.5}, label = c,ax=ax2)
    ax2.set_title('Density Plot with Attribute 2 (X2)')
    ax2.legend(prop={'size': 14}, title = 'Class')
    ax2.set_xlabel('Observed values of X2')
    ax2.set_ylabel('Density')

for c in class_ct:
    subset = data_A[data_A['class'] == c]
    sns.distplot(subset['X3'], hist = False, kde = True, kde_kws = {'fill': True,'linewidth': 2.5}, label = c,ax=ax3)
    ax3.set_title('Density Plot with Attribute 3 (X3)')
    ax3.legend(prop={'size': 14}, title = 'Class')
    ax3.set_xlabel('Observed values of X3')
    ax3.set_ylabel('Density')

for c in class_ct:
    subset = data_A[data_A['class'] == c]
    sns.distplot(subset['X4'], hist = False, kde = True, kde_kws = {'fill': True,'linewidth': 2.5}, label = c,ax=ax4)
    ax4.set_title('Density Plot with Attribute 4 (X4)')
    ax4.legend(prop={'size': 14}, title = 'Class')
    ax4.set_xlabel('Observed values of X4')
    ax4.set_ylabel('Density')

for c in class_ct:
    subset = data_A[data_A['class'] == c]
    sns.distplot(subset['X5'], hist = False, kde = True, kde_kws = {'fill': True,'linewidth': 2.5}, label = c,ax=ax5)
    ax5.set_title('Density Plot with Attribute 5 (X5)')
    ax5.legend(prop={'size': 14}, title = 'Class')
    ax5.set_xlabel('Observed values of X5')
    ax5.set_ylabel('Density')
# Out:
# <ipython-input-39-6dac222efb19>:19: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(subset['X1'], hist = False, kde = True, kde_kws = {'fill': True,'linewidth': 2.5}, label = c,ax=ax1)
# <ipython-input-39-6dac222efb19>:19: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
fig, (ax1,ax2,ax3,ax4,ax5) = plt.subplots(nrows=1, ncols=5, figsize=(30, 8))
sns.set(style="white")
class_ct = [0,1]
# Iterate through each class
    # Draw the density plot
'''
for i in ['X1', 'X2', 'X3', 'X4', 'X5']:
  for c in class_ct:
    subset = data_A[data_A['class'] == c]
    sns.distplot(subset[i], hist = False, kde = True, kde_kws = {'fill': True,'linewidth': 2.5}, label = c)
    ax[int(i[1])-1].set_title('Density Plot with Attribute 1 ()')
    ax[int(i[1])-1].legend(prop={'size': 14}, title = 'Class')
    ax[int(i[1])-1].set_xlabel('Observed values of X')
    ax[int(i[1])-1].set_ylabel('Density')
'''

for c in class_ct:
    subset = data_B[data_B['class'] == c]
    sns.distplot(subset['X1'], hist = False, kde = True, kde_kws = {'fill': True,'linewidth': 2.5}, label = c,ax=ax1)
    ax1.set_title('Density Plot with Attribute 1 (X1)')
    ax1.legend(prop={'size': 14}, title = 'Class')
    ax1.set_xlabel('Observed values of X1')
    ax1.set_ylabel('Density')

for c in class_ct:
    subset = data_B[data_B['class'] == c]
    sns.distplot(subset['X2'], hist = False, kde = True, kde_kws = {'fill': True,'linewidth': 2.5}, label = c,ax=ax2)
    ax2.set_title('Density Plot with Attribute 2 (X2)')
    ax2.legend(prop={'size': 14}, title = 'Class')
    ax2.set_xlabel('Observed values of X2')
    ax2.set_ylabel('Density')

for c in class_ct:
    subset = data_B[data_B['class'] == c]
    sns.distplot(subset['X3'], hist = False, kde = True, kde_kws = {'fill': True,'linewidth': 2.5}, label = c,ax=ax3)
    ax3.set_title('Density Plot with Attribute 3 (X3)')
    ax3.legend(prop={'size': 14}, title = 'Class')
    ax3.set_xlabel('Observed values of X3')
    ax3.set_ylabel('Density')

for c in class_ct:
    subset = data_B[data_B['class'] == c]
    sns.distplot(subset['X4'], hist = False, kde = True, kde_kws = {'fill': True,'linewidth': 2.5}, label = c,ax=ax4)
    ax4.set_title('Density Plot with Attribute 4 (X4)')
    ax4.legend(prop={'size': 14}, title = 'Class')
    ax4.set_xlabel('Observed values of X4')
    ax4.set_ylabel('Density')

for c in class_ct:
    subset = data_B[data_B['class'] == c]
    sns.distplot(subset['X5'], hist = False, kde = True, kde_kws = {'fill': True,'linewidth': 2.5}, label = c,ax=ax5)
    ax5.set_title('Density Plot with Attribute 5 (X5)')
    ax5.legend(prop={'size': 14}, title = 'Class')
    ax5.set_xlabel('Observed values of X5')
    ax5.set_ylabel('Density')
# Out:
# <ipython-input-40-ad4e881f311e>:19: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(subset['X1'], hist = False, kde = True, kde_kws = {'fill': True,'linewidth': 2.5}, label = c,ax=ax1)
# <ipython-input-40-ad4e881f311e>:19: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# Normalize the Data

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
data_St_A = sc.fit_transform(X_A[:])
data_St_B = sc.fit_transform(X_B[:])

# print(data_St_A)

# %%
data_St_A_0 = sc.fit_transform(X_A_0[:])
data_St_A_1 = sc.fit_transform(X_A_1[:])
data_St_B_0 = sc.fit_transform(X_B_0[:])
data_St_B_1 = sc.fit_transform(X_B_1[:])

# No help with standardizing data

# %%
parts_A
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7a126a55b5b0>,
# ...
#  'cmeans': <matplotlib.collections.LineCollection at 0x7a126a55b550>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7a126a598a00>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7a126a598e20>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7a126a599240>}

# %%
# all_y_true

# %%
# all_y_scores

# %%
X_train, X_test, y_train, y_test = train_test_split(X_B, Y_B, test_size=0.20, random_state=7, stratify=y)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)

train_score = {}
test_score = {}
n_neighbors = np.arange(2, 30, 1)
for neighbor in n_neighbors:
    knn = KNeighborsClassifier(n_neighbors=neighbor)
    knn.fit(X_train, y_train)
    train_score[neighbor]=knn.score(X_train, y_train)
    test_score[neighbor]=knn.score(X_test, y_test)
# Out:
# (80, 5)
# (20, 5)
# (80,)
# (20,)

# %%
print(train_score)
print(test_score)
'''
for key, value in test_score.items():
    if value==max(test_score.values()):
        print(key)
'''
# Out:
# {2: 0.825, 3: 0.875, 4: 0.8125, 5: 0.825, 6: 0.825, 7: 0.8375, 8: 0.8, 9: 0.825, 10: 0.8, 11: 0.85, 12: 0.8125, 13: 0.8125, 14: 0.8125, 15: 0.7875, 16: 0.7625, 17: 0.775, 18: 0.7375, 19: 0.75, 20: 0.7375, 21: 0.7625, 22: 0.725, 23: 0.7375, 24: 0.725, 25: 0.75, 26: 0.7375, 27: 0.725, 28: 0.6875, 29: 0.7125}
# {2: 0.8, 3: 0.85, 4: 0.85, 5: 0.8, 6: 0.8, 7: 0.9, 8: 0.85, 9: 0.85, 10: 0.85, 11: 0.85, 12: 0.85, 13: 0.85, 14: 0.8, 15: 0.8, 16: 0.8, 17: 0.8, 18: 0.8, 19: 0.8, 20: 0.85, 21: 0.8, 22: 0.8, 23: 0.8, 24: 0.85, 25: 0.8, 26: 0.8, 27: 0.8, 28: 0.9, 29: 0.85}
# '\nfor key, value in test_score.items():\n    if value==max(test_score.values()):\n        print(key)\n'

# %%
parameter={'n_neighbors': np.arange(2, 30, 1)}
knn=KNeighborsClassifier()
knn_cv=GridSearchCV(knn, param_grid=parameter, verbose=1)
knn_cv.fit(X_train, y_train)
print(knn_cv.best_params_)
# Out:
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# {'n_neighbors': 11}

# %%
for i in ['X1', 'X2', 'X3', 'X4', 'X5']:
      # sns.distplot(subset[i], hist = False, kde = True, kde_kws = {'fill': True,'linewidth': 2.5}, label = c)
      print(int(i[1]))
# Out:
# 1
# 2
# 3
# 4
# 5
